# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# # EDA of passengerID

# %%
df.PassengerId.value_counts()
# Out:
# 891    1
# 293    1
# 304    1
# 303    1
# 302    1
# 301    1
# 300    1
# 299    1
# 298    1
# 297    1
# 296    1
# 295    1
# 294    1
# 292    1
# 306    1
# 291    1
# 290    1
# 289    1
# 288    1
# 287    1
# 286    1
# 285    1
# 284    1
# 283    1
# 282    1
# 281    1
# 305    1
# 307    1
# 279    1
# 321    1
#       ..
# 561    1
# 560    1
# 584    1
# 585    1
# 586    1
# 587    1
# 610    1
# 609    1
# 608    1
# 607    1
# 606    1
# 605    1
# 604    1
# 603    1
# 602    1
# 601    1
# 600    1
# 599    1
# 598    1
# 597    1
# 596    1
# 595    1
# 594    1
# 593    1
# 592    1
# 591    1
# 590    1
# 589    1
# 588    1
# 1      1
# Name: PassengerId, dtype: int64

# %%
##So the variable PassengerId is continuous'.
## checking form missing values.
df[df.PassengerId.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
##here the variable dosen't have any missing values. so now lets calculate the min, max, mean and standard deviation.

# %% [markdown]
# # Min

# %%
df.PassengerId.min()
# Out:
# 1

# %% [markdown]
# # Max

# %%
df.PassengerId.max()
# Out:
# 891

# %% [markdown]
# # Mean

# %%
df.PassengerId.mean()
# Out:
# 446.0

# %% [markdown]
# # Std.Deviation

# %%
df.PassengerId.std()
# Out:
# 257.3538420152301

# %%
#Now plot the Histogram descibing the distrubution of variable
df.PassengerId.hist()

# %%
#consider the 2nd variable Survived
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
#Here 0 represents 'non survival' whereas 1 represents 'survival'.
#Now check for missing values.
df[df.Survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#No missing values. 
#Now plot the histogram
df.Survived.value_counts().plot(kind='barh')

# %%
#Now the 3rd variable Pclass
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
#The variable seems categorical with possible values as 1, 2 and 3.
#Missing Values
df[df.Pclass.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#So no missing values
#Histogram
df.Pclass.value_counts().plot(kind='barh')

# %% [markdown]
# # Sex

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
#catogerical as male and female
#Missing Values?
df[df.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#No missing values
#Histogram
df.Sex.value_counts().plot(kind='bar')

# %% [markdown]
# # Age

# %%
df.Age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
# 30.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 27.00    18
# 35.00    18
# 26.00    18
# 32.00    18
# 31.00    17
# 16.00    17
# 23.00    15
# 20.00    15
# 34.00    15
# 33.00    15
# 39.00    14
# 17.00    13
# 40.00    13
# 42.00    13
# 45.00    12
# 38.00    11
# 50.00    10
# 2.00     10
# 4.00     10
# 48.00     9
#          ..
# 0.75      2
# 45.50     2
# 64.00     2
# 30.50     2
# 0.83      2
# 32.50     2
# 40.50     2
# 71.00     2
# 28.50     2
# 63.00     2
# 59.00     2
# 57.00     2
# 55.00     2
# 70.00     2
# 55.50     1
# 24.50     1
# 34.50     1
# 0.92      1
# 36.50     1
# 0.42      1
# 23.50     1
# 12.00     1
# 20.50     1
# 14.50     1
# 80.00     1
# 74.00     1
# 70.50     1
# 66.00     1
# 53.00     1
# 0.67      1
# Name: Age, dtype: int64

# %%
#So the variable is continuous
#Missing Values?
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
#It has 177 missing values

# %% [markdown]
# # Min

# %%
df.Age.min()
# Out:
# 0.41999999999999998

# %% [markdown]
# # Max

# %%
df.Age.max()
# Out:
# 80.0

# %% [markdown]
# # Mean

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %% [markdown]
# # Std. Deviation

# %%
df.Age.std()
# Out:
# 14.526497332334044

# %% [markdown]
# # Histogram

# %%
df.Age.hist()

# %% [markdown]
# # SibSp

# %%
df.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
#So continuous variable
#Missing values
df[df.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#no missing values

# %%
#Histogram
df.Sex.value_counts().plot(kind='bar')

# %% [markdown]
# # Min

# %%
df.SibSp.min()
# Out:
# 0

# %% [markdown]
# # Max

# %%
df.SibSp.max()
# Out:
# 8

# %% [markdown]
# # Mean

# %%
df.SibSp.mean()
# Out:
# 0.5230078563411896

# %% [markdown]
# # Std.Deviation

# %%
df.SibSp.std()
# Out:
# 1.1027434322934275

# %% [markdown]
# # Histogram

# %%
df.SibSp.hist()

# %% [markdown]
# # Parch

# %%
df.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
#So continuous variable
#Missing values?
df[df.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#no missing values

# %% [markdown]
# # Min

# %%
df.Parch.min()
# Out:
# 0

# %% [markdown]
# # Max

# %%
df.Parch.max()
# Out:
# 6

# %% [markdown]
# # Mean

# %%
df.Parch.mean()
# Out:
# 0.38159371492704824

# %% [markdown]
# # Std.Deviation

# %%
df.Parch.std()
# Out:
# 0.8060572211299559

# %% [markdown]
# # Histogram

# %%
df.Parch.hist()

# %% [markdown]
# # Ticket

# %%
df.Ticket.value_counts()
# Out:
# CA. 2343            7
# 1601                7
# 347082              7
# 347088              6
# CA 2144             6
# 3101295             6
# 382652              5
# S.O.C. 14879        5
# PC 17757            4
# 347077              4
# 4133                4
# LINE                4
# 349909              4
# 17421               4
# W./C. 6608          4
# 19950               4
# 113760              4
# 2666                4
# 113781              4
# 29106               3
# C.A. 34651          3
# 24160               3
# 13502               3
# PC 17582            3
# 230080              3
# 248727              3
# 345773              3
# 110152              3
# 110413              3
# 35273               3
#                    ..
# SOTON/OQ 3101317    1
# 345769              1
# 219533              1
# 233639              1
# 244358              1
# SOTON/OQ 392086     1
# 382651              1
# STON/O2. 3101283    1
# 347089              1
# A/5 2817            1
# ...

# %%
#So categorical variable
#Missing values?
df[df.Ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#No missing value
#Histogram
df.Ticket.value_counts().plot(kind='bar')

# %% [markdown]
# # Fare

# %%
df.Fare.value_counts()
# Out:
# 8.0500      43
# 13.0000     42
# 7.8958      38
# 7.7500      34
# 26.0000     31
# 10.5000     24
# 7.9250      18
# 7.7750      16
# 26.5500     15
# 7.2292      15
# 0.0000      15
# 7.2500      13
# 7.8542      13
# 8.6625      13
# 7.2250      12
# 9.5000       9
# 16.1000      9
# 24.1500      8
# 15.5000      8
# 56.4958      7
# 14.5000      7
# 7.0500       7
# 52.0000      7
# 31.2750      7
# 69.5500      7
# 14.4542      7
# 7.7958       6
# 26.2500      6
# 30.0000      6
# 27.9000      6
#             ..
# 211.5000     1
# 12.2750      1
# 8.6542       1
# 6.9500       1
# 22.0250      1
# 7.1417       1
# 10.1708      1
# 17.4000      1
# 8.3000       1
# 16.0000      1
# 10.5167      1
# 15.0458      1
# 50.4958      1
# 8.4042       1
# 26.2833      1
# 12.6500      1
# 8.7125       1
# 22.5250      1
# 15.7500      1
# 9.2167       1
# 21.6792      1
# 14.1083      1
# 15.1000      1
# 7.3125       1
# 8.1125       1
# 13.8583      1
# 34.6542      1
# ...

# %%
# So continuous variable
# Missing values
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# # Min

# %%
df.Fare.min()
# Out:
# 0.0

# %% [markdown]
# # Max

# %%
df.Fare.max()
# Out:
# 512.32920000000001

# %% [markdown]
# # Mean

# %%
df.Fare.mean()
# Out:
# 32.2042079685746

# %% [markdown]
# # Std.Deviation

# %%
df.Fare.std()
# Out:
# 49.693428597180905

# %% [markdown]
# # Histogram

# %%
df.Fare.hist()

# %% [markdown]
# # Cabin

# %%
df.Cabin.value_counts()
# Out:
# C23 C25 C27        4
# B96 B98            4
# G6                 4
# F33                3
# D                  3
# C22 C26            3
# F2                 3
# E101               3
# B49                2
# B58 B60            2
# D36                2
# C52                2
# E121               2
# E25                2
# D33                2
# C83                2
# C92                2
# E44                2
# C93                2
# C123               2
# F G73              2
# B57 B59 B63 B66    2
# B18                2
# E67                2
# E8                 2
# B51 B53 B55        2
# C78                2
# C2                 2
# B28                2
# E24                2
#                   ..
# A26                1
# C30                1
# B78                1
# C70                1
# C118               1
# C111               1
# B94                1
# D37                1
# C104               1
# C46                1
# T                  1
# E68                1
# ...

# %%
#Categorical variable
#Missing values?
df[df.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %%
#So 687 missing values
#Histogram
df.Cabin.value_counts().plot(kind='bar')

# %% [markdown]
# # Embarked

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
#So categorical variable
#Missing values
df[df.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
#So 2 missing values
#Histogram
df.Embarked.value_counts().plot(kind='barh')
